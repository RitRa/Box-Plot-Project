# %%
#import libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

# we need to skip the first 9 rows as it is full of notes
df = pd.read_csv("https://cli.fusio.net/cli/climate_data/webdata/dly2007.csv",skiprows=9)
df['date'] = pd.to_datetime(df['date'])
# Set the datetime column as the index
df.index = df['date'] 
# create a new column for month
df['month'] = df['date'].dt.strftime('%b')
# create a new column for year
df['year'] = df['date'].dt.strftime('%Y')

# %% [markdown]
# ## 3. Explain any relevant terminology such as the terms quartile and percentile.

# %% [markdown]
# ![boxplot_terminiology](boxplotexample.png)

# %% [markdown]
# Box plots are made up of:
#
# - Median
# - whiskers
# - Inter-quartile range
# - upper quartile
# - lower quartile
# - outliers

# %% [markdown]
# ###  Median
#
# The median of a dataset it the middle. It is shown in the line dividing the box.

# %%
np.median(df['rain'])
# Out:
# 0.25

# %% [markdown]
# ### Whiskers
# Shows the full spread of all the data. They show the highest(upper whisker) and lowest points (lower whisker).
#
# ### Inter-quartile range
# The middle box represents 50% of the data. The range of data from lower to upper quartile is referred to as the inter-quartile range.
#
# ### Upper Quartile
# Seventy-five percent of the data fall below the upper quartile. Between the end of the box and the upper whisker.
#
# ### Lower Quartile
# Twenty-five percent of the data fall below the upper quartile. Between the bottom of the box and the lower whisker.
#
# ### Outlier
# Outliers beyond whiskers represent the extremes. They are usually treated as abnormal values usually representing very high or very low values.

# %% [markdown]
# ## 4. Compare the box plot to alternatives.
#
# Alternatives to the boxplot include:
#
# - Histogram
# - The Violin plot
# - Boxenplot
# - Bean plot
# - Swarm Plot
# - Strip Plot
# - Diamonds
# - Bar plots

# %% [markdown]
# The beauty of the boxplot is that it was designed so that any statistican could draw them by hand but as technology has developed we can look at more complex ways to show distributions in the similar compact form of a box plot.

# %% [markdown]
# ### The Violin Plot
#
# Note that the Violin plot is closely related to Tukey's boxplot.
#
# The violin plot combines the boxplot with a kernel density estimation (KDE) of the underlying distribution. There are two modifications: the box plot is black and the median line is replaced with a circle. Outliers are contained within the kernel density estimation. They are a visually pleasing way of representing your data.
#
# A Violin plot is more informative than a plain box plot as it shows the full distribution of data.

# %%
# %matplotlib inline

fig, ax = plt.subplots()
fig.set_size_inches((10,10))
plot = sns.violinplot(x = df['year'], y = df['rain'])

plot.set_title('Yearly Rainfall Comparison in Dungarvan 1995 - 1997',fontsize=20)
plot.set_ylabel('Rainfall',fontsize=20)
plot.set_xlabel('Year',fontsize=20)

plt.show()

# %% [markdown]
# ### Boxenplot

# %%
# %matplotlib inline

fig, ax = plt.subplots()
fig.set_size_inches((10,10))

plot = sns.boxenplot(x = df['year'], y = df['rain'])

plot.set_title('Yearly Rainfall Comparison in Dungarvan 1995 - 1997',fontsize=20)
plot.set_ylabel('Rainfall',fontsize=20)
plot.set_xlabel('Year',fontsize=20)

plt.show()

# %% [markdown]
# ### Swarm Plot

# %%
# %matplotlib inline

fig, ax = plt.subplots()
fig.set_size_inches((10,10))

sns.swarmplot(x = df['year'], y = df['rain'])

# %% [markdown]
# ### Strip Plot

# %%
# %matplotlib inline

fig, ax = plt.subplots()
fig.set_size_inches((10,10))

ax = sns.stripplot(x = df['year'], y = df['rain'],  jitter=True)

# %%
sns.catplot(x = df['year'], y = df['rain'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-d20c9329bb9e> in <module>()
# ----> 1 sns.catplot(x = df['year'], y = df['rain'])
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3750
#    3751     # Initialize the facets
# -> 3752     g = FacetGrid(**facet_kws)
#    3753
#    3754     # Draw the plot onto the facets
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py in __init__(self, data, row, col, hue, col_wrap, sharex, sharey, height, aspect, palette, row_order, col_order, hue_order, hue_kws, dropna, legend_out, despine, margin_titles, xlim, ylim, subplot_kws, gridspec_kws, size)
#     255         # Make a boolean mask that is True anywhere there is an NA
#     256         # value in one of the faceting variables, but only if dropna is True
# --> 257         none_na = np.zeros(len(data), np.bool)
#     258         if dropna:
#     259             row_na = none_na if row is None else data[row].isnull()
#
# TypeError: object of type 'NoneType' has no len()

# %% [markdown]
# ### The notched box plot

# %%
# library & dataset
import seaborn as sns
df = sns.load_dataset('iris')
 
# Add notch
sns.boxplot( x=df["species"], y=df["sepal_length"], notch=True)
#sns.plt.show()

# %% [markdown]
# https://stackoverflow.com/questions/33381330/histogram-with-boxplot-above-in-python

# %%
x = np.random.randn(100)

f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, 
                                    gridspec_kw={"height_ratios": (.15, .85)})

sns.boxplot(x, ax=ax_box)
sns.distplot(x, ax=ax_hist)

ax_box.set(yticks=[])
sns.despine(ax=ax_hist)
sns.despine(ax=ax_box, left=True)

# %% [markdown]
# References:
#
# https://seaborn.pydata.org/tutorial/categorical.html#categorical-tutorial
#
# https://en.wikipedia.org/wiki/Violin_plot
#
# http://vita.had.co.nz/papers/boxplots.pdf
